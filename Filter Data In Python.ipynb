# %% [markdown]
# Filter Data in Python

# %%
# filter (function, iterable)

data = [100,200,300,400]

filtered = list(filter(lambda x: x > 150, data))
print(filtered)
# Out:
# [200, 300, 400]

# %%
data = [100,200,300,400]

filtered = list(filter(lambda x: x > 250, data))
print(filtered)
# Out:
# [300, 400]

# %%
data = [100, -1, 200, None, 0]

cleared_data = list(filter(lambda x:x is not None and x > 0, data)) 
print(cleared_data)
# Out:
# [100, 200]

# %%
employees = [
    {"name": "Alice", "Salary": 70000},
    {"name": "Bob", "Salary": 50000},
    {"name": "Charlie", "Salary": 60000}
]

high_earners = list(filter(lambda emp: emp["Salary"] > 55000, employees))
print(high_earners)

indians = list(filter(lambda x: x["Salary"] == 70000, employees))
print(indians)
# Out:
# [{'name': 'Alice', 'Salary': 70000}, {'name': 'Charlie', 'Salary': 60000}]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 10
#       6
#       7 high_earners = list(filter(lambda emp: emp["Salary"] > 55000, employees))
#       8 print(high_earners)
#       9
# ---> 10 indians = list(filter(lambda x: x["country"] == "India", employees))
#      11 print(indians)
#
# Cell In[12], line 10, in <lambda>(x)
# ---> 10 indians = list(filter(lambda x: x["country"] == "India", employees))
#
# KeyError: 'country'

# %%
try:
    month = int(input("Enter the month of dob:"))
except ValueError:
    print("That's not a number")
# Out:
# That's not a number

# %%
try:
    month = int(input("Enter the month of dob:"))
except ValueError:
    print("That's not a number")
else:
    print(month)
finally:
    print("We are done")
# Out:
# 5
# We are done

# %% [markdown]
# Reading data from json files

# %%
import json

schemas = json.load(open('schemas.json', 'r'))

# %%
type(schemas)
# Out:
# dict

# %%
schemas.keys()
# Out:
# dict_keys(['departments', 'categories', 'orders', 'products', 'customers', 'order_items'])

# %%
schemas.get('orders')
# Out:
# [{'column_name': 'order_id', 'data_type': 'integer', 'column_position': 1},
#  {'column_name': 'order_date', 'data_type': 'string', 'column_position': 2},
#  {'column_name': 'customer_id',
#   'data_type': 'timestamp',
#   'column_position': 3},
#  {'column_name': 'order_status', 'data_type': 'string', 'column_position': 4}]

# %%
schemas['orders']
# Out:
# [{'column_name': 'order_id', 'data_type': 'integer', 'column_position': 1},
#  {'column_name': 'order_date', 'data_type': 'string', 'column_position': 2},
#  {'column_name': 'customer_id',
#   'data_type': 'timestamp',
#   'column_position': 3},
#  {'column_name': 'order_status', 'data_type': 'string', 'column_position': 4}]

# %%
column_details = schemas['orders']
print(column_details)
# Out:
# [{'column_name': 'order_id', 'data_type': 'integer', 'column_position': 1}, {'column_name': 'order_date', 'data_type': 'string', 'column_position': 2}, {'column_name': 'customer_id', 'data_type': 'timestamp', 'column_position': 3}, {'column_name': 'order_status', 'data_type': 'string', 'column_position': 4}]

# %%
[col['column_name'] for col in column_details]
# Out:
# ['order_id', 'order_date', 'customer_id', 'order_status']

# %%
list(map(lambda col: col['column_name'], column_details))
# Out:
# ['order_id', 'order_date', 'customer_id', 'order_status']

# %%
sorting_key = input('Enter the column name to sort by: ')
columns = sorted(column_details, key=lambda col:col[sorting_key])
print(columns)
# Out:
# [{'column_name': 'customer_id', 'data_type': 'timestamp', 'column_position': 3}, {'column_name': 'order_date', 'data_type': 'string', 'column_position': 2}, {'column_name': 'order_id', 'data_type': 'integer', 'column_position': 1}, {'column_name': 'order_status', 'data_type': 'string', 'column_position': 4}]

# %% [markdown]
# Extracting column from json file

# %%
sorting_key = input('Enter the column name to sort by: ')
columns = sorted(column_details, key=lambda col:col[sorting_key])
[col['column_name'] for col in columns]
# Out:
# ['customer_id', 'order_date', 'order_id', 'order_status']

# %%
def get_column_names(schemas, ds_name, sorting_key = 'column_position'):
    column_details = schemas[ds_name]
    columns = sorted(column_details, key=lambda col:col[sorting_key])
    return [col['column_name'] for col in columns]

# %%
get_column_names(schemas, 'customers')
# Out:
# ['customer_id',
#  'customer_fname',
#  'customer_lname',
#  'customer_email',
#  'customer_password',
#  'customer_street',
#  'customer_city',
#  'customer_state',
#  'customer_zipcode']
